# %% [markdown]
# ## 1. About the DWD Open Data Portal
#
# The data of the Climate Data Center (CDC) of the DWD (Deutscher Wetterdienst, German Weather Service) is provided on an **FTP server**. <br> **FTP** stands for _File Transfer Protocol_.
#
# Open the FTP link ftp://opendata.dwd.de/climate_environment/CDC/ in your browser (copy-paste) and find our how it is structured hierarchically.
#
# You can also open the link with **HTTPS** (Hypertext Transfer Protocol Secure): https://opendata.dwd.de/climate_environment/CDC/
#
# We are interested in downloading the metadata of daily precipitation to get information related to their stations

# %%
import requests
from bs4 import BeautifulSoup
import os
import re # to use regex expressions 
import tqdm
import pandas as pd
import geopandas as gpd

# URL of the DWD website
url_base = "https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/"
url_temporal_resolution = "daily/"
url_parameter = "more_precip/"
url_subdir = "historical/"
url_full = os.path.join(url_base, url_temporal_resolution, url_parameter, url_subdir)

# Directory to save the downloaded files
download_dir = "../data/original/dwd/" +  url_temporal_resolution + url_parameter + url_subdir

# Create the directory if it doesn't exist
if not os.path.exists(download_dir):
    os.makedirs(download_dir)

print("download dir: ", download_dir)

# Directory and name to save the CSV file to create the layer for sub-task 1.2
outfname = r"../data/Selected_Stations_Nordrhein_Westfalen.csv"
# Out:
# download dir:  ../data/original/dwd/daily/more_precip/historical/

# %%
url_full
# Out:
# 'https://opendata.dwd.de/climate_environment/CDC/observations_germany/climate/daily/more_precip/historical/'

# %%
def grab_file(file_url, download_dir):
        # get only the file name from the full url
        file_name = file_url.split("/")[-1]
        # Download the file
        file_path =os.path.join(download_dir, file_name)
        with open(file_path, "wb") as file:
            file.write(requests.get(file_url).content)

# %%
# Send an HTTP request to the URL
response = requests.get(url_full)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, "html.parser")
    # Look for the metadata file
    links = soup.find_all(href=re.compile("Beschreibung"))
    # Take the url of the file
    file_name = links[0].get("href")
    # Download the file
    grab_file(os.path.join(url_full, file_name), download_dir)
    print(f"Downloaded: {download_dir+file_name}")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# Downloaded: ../data/original/dwd/daily/more_precip/historical/RR_Tageswerte_Beschreibung_Stationen.txt

# %%
# get station path
file_path = os.path.join(download_dir,file_name)
# read the header of the file
header = open(file_path, encoding="latin").readline().split()
header
# Out:
# ['Stations_id',
#  'von_datum',
#  'bis_datum',
#  'Stationshoehe',
#  'geoBreite',
#  'geoLaenge',
#  'Stationsname',
#  'Bundesland',
#  'Abgabe']

# %%
# translation dictionary
translate = \
{'Stations_id':'station_id',
 'von_datum':'date_from',
 'bis_datum':'date_to',
 'Stationshoehe':'altitude',
 'geoBreite': 'latitude',
 'geoLaenge': 'longitude',
 'Stationsname':'name',
 'Bundesland':'state'}

# %%
#pd.read_csv?

# %%
df_stations_2 = pd.read_fwf(file_path,
                          skiprows=[0,1],
                          names=translate,
                          encoding="latin", 
                          parse_dates=["von_datum","bis_datum"],
                          dtype={"Stations_id":str}
                          #index_col="Stations_id"
                         )
df_stations_2
# Out:
# C:\Users\amr_d\AppData\Local\Temp\ipykernel_348\2950410865.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_stations_2 = pd.read_fwf(file_path,
#       Stations_id  von_datum bis_datum  Stationshoehe  geoBreite  \
# 1        19120101 1986-06-30       478        47.8413     8.8493
# 2        19510101 2006-12-31       138        50.8066     6.0996
# 3        18910101 2011-03-31       202        50.7827     6.0941
# 4        19510101 1979-10-31       243        50.7683     6.1207
# 6        19821101 2024-09-22       455        48.8361    10.0598
# ...           ...        ...       ...            ...        ...
# 19898    20240101 2024-09-22        39        52.4970    13.2820
# 19911    19631101 1986-09-30       215        50.9625    10.0663
# 19917    20240325 2024-09-22       153        49.9321     8.0767
# 19993    18970507 1935-12-31         4        53.6870     9.6757
# 19995    20240801 2024-09-22        40        54.0659    10.6502
#
#                     geoLaenge         Stationsname Bundesland
# 1                        Aach    Baden-Württemberg       Frei
# 2         Aachen (Kläranlage)  Nordrhein-Westfalen       Frei
# 3                      Aachen  Nordrhein-Westfalen       Frei
# 4                Aachen-Brand  Nordrhein-Westfalen       Frei
# 6          Aalen-Unterrombach    Baden-Württemberg       Frei
# ...                       ...                  ...        ...
# 19898         Berlin-Halensee               Berlin       Frei
# 19911    Gerstungen/Thüringen            Thüringen       Frei
# 19917  Schwabenheim a.d. Selz      Rheinland-Pfalz        NaN
# 19993                Uetersen   Schleswig-Holstein       Frei
# 19995           Süsel-Kesdorf   Schleswig-Holstein       Frei
#
# [6492 rows x 8 columns]

# %%
# read the stations dataframe
df_stations = pd.read_fwf(file_path,
                          skiprows=2,
                          names=header,
                          encoding="latin", 
                          parse_dates=["von_datum","bis_datum"],
                          dtype={"Stations_id":str} 
                          #index_col="Stations_id"
                         )
df_stations
# Out:
#      Stations_id  von_datum  bis_datum  Stationshoehe  geoBreite  geoLaenge  \
# 0          00001 1912-01-01 1986-06-30            478    47.8413     8.8493
# 1          00002 1951-01-01 2006-12-31            138    50.8066     6.0996
# 2          00003 1891-01-01 2011-03-31            202    50.7827     6.0941
# 3          00004 1951-01-01 1979-10-31            243    50.7683     6.1207
# 4          00006 1982-11-01 2024-09-22            455    48.8361    10.0598
# ...          ...        ...        ...            ...        ...        ...
# 6487       19898 2024-01-01 2024-09-22             39    52.4970    13.2820
# 6488       19911 1963-11-01 1986-09-30            215    50.9625    10.0663
# 6489       19917 2024-03-25 2024-09-22            153    49.9321     8.0767
# 6490       19993 1897-05-07 1935-12-31              4    53.6870     9.6757
# 6491       19995 2024-08-01 2024-09-22             40    54.0659    10.6502
#
#                 Stationsname           Bundesland Abgabe
# 0                       Aach    Baden-Württemberg   Frei
# 1        Aachen (Kläranlage)  Nordrhein-Westfalen   Frei
# 2                     Aachen  Nordrhein-Westfalen   Frei
# 3               Aachen-Brand  Nordrhein-Westfalen   Frei
# 4         Aalen-Unterrombach    Baden-Württemberg   Frei
# ...                      ...                  ...    ...
# 6487         Berlin-Halensee               Berlin   Frei
# 6488    Gerstungen/Thüringen            Thüringen   Frei
# 6489  Schwabenheim a.d. Selz      Rheinland-Pfalz    NaN
# 6490                Uetersen   Schleswig-Holstein   Frei
# 6491           Süsel-Kesdorf   Schleswig-Holstein   Frei
#
# [6492 rows x 9 columns]

# %% [markdown]
# Check all the different values in the "state" column. You can use the function <code>.unique()</code> for this.

# %%
df_stations.rename(columns=translate,inplace=True)

# %%
df_stations.loc[:,"state"].unique()
# Out:
# array(['Baden-Württemberg', 'Nordrhein-Westfalen', 'Hessen', 'Bayern',
#        'Niedersachsen', 'Sachsen-Anhalt', 'Rheinland-Pfalz', 'Sachsen',
#        'Mecklenburg-Vorpommern', 'Schleswig-Holstein', 'Brandenburg',
#        'Thüringen', 'Saarland', 'Berlin', 'Bremen', 'Hamburg', 'Tirol'],
#       dtype=object)

# %% [markdown]
# Select only stations in NRW which are still active (date_to is later than 2023) and which starting recording information at least in 1950.

# %%
#df_stations.query?

# %%
# filter stations only in Nordrhein-Westfalen which are active and older than 1950
df_stations_short = df_stations.query("state == 'Nordrhein-Westfalen' and date_to >= 2023 and date_from < 1950")

# %%
df_stations_short
# Out:
#      station_id  date_from    date_to  altitude  latitude  longitude  \
# 75        00079 1931-01-01 2024-09-20       160   50.6718     7.0155
# 104       00110 1931-01-01 2024-09-22        65   52.0487     7.4877
# 174       00187 1941-01-01 2024-09-22       265   51.4188     7.9126
# 292       00325 1941-01-01 2024-09-22       127   51.7948     8.0718
# 349       00389 1931-01-01 2024-09-22       436   51.0148     8.4318
# ...         ...        ...        ...       ...       ...        ...
# 5104      05579 1941-01-01 2024-09-22       273   51.5892     9.0296
# 5143      05619 1931-01-01 2024-09-22       360   51.1637     7.4234
# 5218      05699 1941-01-01 2024-09-22       312   51.5427     8.7784
# 5236      05717 1937-01-01 2024-09-22       134   51.2256     7.1052
# 5305      05791 1900-06-07 2024-09-22       189   50.6575     6.6945
#
#                              name                state Abgabe
# 75            Alfter-Volmershoven  Nordrhein-Westfalen   Frei
# 104                    Altenberge  Nordrhein-Westfalen   Frei
# 174               Arnsberg-Holzen  Nordrhein-Westfalen   Frei
# 292                Beckum-Vellern  Nordrhein-Westfalen   Frei
# 349         Berleburg, Bad-Arfeld  Nordrhein-Westfalen   Frei
# ...                           ...                  ...    ...
# 5104  Willebadessen-Borlinghausen  Nordrhein-Westfalen   Frei
# 5143         Wipperfürth-Gardeweg  Nordrhein-Westfalen   Frei
# 5218            Wünnenberg-Eilern  Nordrhein-Westfalen   Frei
# 5236        Wuppertal-Buchenhofen  Nordrhein-Westfalen   Frei
# 5305                Zülpich-Enzen  Nordrhein-Westfalen   Frei
#
# [83 rows x 9 columns]

# %%
# get the links. 
links = soup.find_all(href=[re.compile("RR_"+x) for x in df_stations_short.loc[:,"station_id"]])
links
# Out:
# [<a href="tageswerte_RR_00079_19310101_20231231_hist.zip">tageswerte_RR_00079_19310101_20231231_hist.zip</a>,
#  <a href="tageswerte_RR_00110_19310101_20231231_hist.zip">tageswerte_RR_00110_19310101_20231231_hist.zip</a>,
#  <a href="tageswerte_RR_00187_19410101_20231231_hist.zip">tageswerte_RR_00187_19410101_20231231_hist.zip</a>,
#  <a href="tageswerte_RR_05513_18910901_20231231_hist.zip">tageswerte_RR_05513_18910901_20231231_hist.zip</a>,
#  <a href="tageswerte_RR_05579_19410101_20231231_hist.zip">tageswerte_RR_05579_19410101_20231231_hist.zip</a>,
#  <a href="tageswerte_RR_05619_19310101_20231231_hist.zip">tageswerte_RR_05619_19310101_20231231_hist.zip</a>,
#  <a href="tageswerte_RR_05699_19410101_20231231_hist.zip">tageswerte_RR_05699_19410101_20231231_hist.zip</a>,
#  <a href="tageswerte_RR_05717_19370101_20231231_hist.zip">tageswerte_RR_05717_19370101_20231231_hist.zip</a>,
#  <a href="tageswerte_RR_05791_19000607_20231231_hist.zip">tageswerte_RR_05791_19000607_20231231_hist.zip</a>]

# %%
#soup

# %%
try:
    # iterate through the list
    for link in tqdm.tqdm(links):
        # Take the url of the file
        file_name = link.get("href")
        # Download the file
        grab_file(os.path.join(url_full, file_name), download_dir)
    
except:
    print("Failed to download")

print("Download complete")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 83/83 [01:05<00:00,  1.27it/s]
# Download complete

# %% [markdown]
# extract one of the zip files to look at the content. Identify which file contains the data you are interested in.

# %%
import glob
zip_list = glob.glob(download_dir+"*.zip")
zip_list
# Out:
# ['../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_00079_19310101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_00110_19310101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_00187_19410101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_00325_19410101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_00389_19310101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_00488_19410101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_00554_19460101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_00555_19310101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_00613_19410101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_00617_19410101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_00644_19410101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_00796_19410101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_00871_19410101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_00902_19310101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_00989_19310101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_01024_19310101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_01054_19410101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_01232_19410101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_01246_19410101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_05619_19310101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_05699_19410101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_05717_19370101_20231231_hist.zip',
#  '../data/original/dwd/daily/more_precip/historical\\tageswerte_RR_05791_19000607_20231231_hist.zip']

# %%
from zipfile import ZipFile
# example of the files inside the first zip file
with ZipFile(zip_list[0]) as myzip:
    print(myzip.namelist())
# Out:
# ['Metadaten_Stationsname_Betreibername_00079.html', 'Metadaten_Stationsname_Betreibername_00079.txt', 'Metadaten_Parameter_nieder_tag_00079.html', 'Metadaten_Parameter_nieder_tag_00079.txt', 'Metadaten_Geraete_Neuschneehoehe_00079.html', 'Metadaten_Geraete_Neuschneehoehe_00079.txt', 'Metadaten_Geraete_Niederschlagshoehe_00079.html', 'Metadaten_Geraete_Niederschlagshoehe_00079.txt', 'Metadaten_Geraete_Schneehoehe_00079.html', 'Metadaten_Geraete_Schneehoehe_00079.txt', 'Metadaten_Geographie_00079.txt', 'Metadaten_Fehldaten_00079_19310101_20231231.html', 'Metadaten_Fehldaten_00079_19310101_20231231.txt', 'Metadaten_Fehlwerte_00079_19310101_20231231.txt', 'produkt_nieder_tag_19310101_20231231_00079.txt']

# %%
# use the name pattern to get the file name
with ZipFile(zip_list[0]) as myzip:
    prod_filename = [name for name in myzip.namelist() if name.split("_")[0]=="produkt"][0] 
    print(prod_filename)
# Out:
# produkt_nieder_tag_19310101_20231231_00079.txt

# %%
# Read one of the files as example

with ZipFile(zip_list[0]) as myzip:
    prod_filename = [name for name in myzip.namelist() if name.split("_")[0]=="produkt"][0] 
    
    #open just the product file within archive
    with myzip.open(prod_filename) as myfile:
    # read the time series data in a temporal dataframe
        df_prec = pd.read_csv(myfile, 
                      sep=";", 
                      parse_dates = ["MESS_DATUM"], 
                      index_col = "MESS_DATUM", 
                      na_values = [-999.0],
                    dtype={'STATIONS_ID':int} #easier to be integer because of the different format
                         )
df_prec.head()
# Out:
#             STATIONS_ID  QN_6    RS   RSF  SH_TAG  NSH_TAG  eor
# MESS_DATUM
# 1931-01-01           79     5   5.8   8.0     NaN      NaN  eor
# 1931-01-02           79     5   3.3   1.0     NaN      NaN  eor
# 1931-01-03           79     5   5.4   8.0     NaN      NaN  eor
# 1931-01-04           79     5   0.2   1.0     NaN      NaN  eor
# 1931-01-05           79     5   2.0   8.0     NaN      NaN  eor

# %% [markdown]
# Now repeat the example with all the files in the ziplist. And join them in a dataframe

# %%
df_prec.columns
# Out:
# Index(['STATIONS_ID', 'QN_6', '  RS', ' RSF', 'SH_TAG', 'NSH_TAG', 'eor'], dtype='object')

# %%
df_prec =  df_prec[['  RS','STATIONS_ID' ]]
df_prec
# Out:
#               RS  STATIONS_ID
# MESS_DATUM
# 1931-01-01   5.8           79
# 1931-01-02   3.3           79
# 1931-01-03   5.4           79
# 1931-01-04   0.2           79
# 1931-01-05   2.0           79
# ...          ...          ...
# 2023-12-27   0.0           79
# 2023-12-28   0.0           79
# 2023-12-29   0.4           79
# 2023-12-30   0.0           79
# 2023-12-31   0.0           79
#
# [33237 rows x 2 columns]

# %%
df_prec[(df_prec.index.year >= 1950)]
# Out:
#               RS  STATIONS_ID
# MESS_DATUM
# 1950-01-01   0.0           79
# 1950-01-02  13.0           79
# 1950-01-03   1.0           79
# 1950-01-04   2.8           79
# 1950-01-05   0.8           79
# ...          ...          ...
# 2023-12-27   0.0           79
# 2023-12-28   0.0           79
# 2023-12-29   0.4           79
# 2023-12-30   0.0           79
# 2023-12-31   0.0           79
#
# [27027 rows x 2 columns]

# %%
# create an empty dataFrame to merge the temperature data to
df_prec_long = pd.DataFrame()
# iterate through the zipfiles
for zip_file in zip_list:
    with ZipFile(zip_file) as myzip:
        #we are only interested in the file starting with 'produkt_'
        prod_filename = [name for name in myzip.namelist() if name.split("_")[0]=="produkt"][0] 
        
        #open just the product file within archive
        with myzip.open(prod_filename) as myfile:
            # read the time series data in a temporal dataframe
            df_dummy = pd.read_csv(myfile, 
                                  sep=";", 
                                  parse_dates = ["MESS_DATUM"], 
                                  index_col = "MESS_DATUM", 
                                  na_values = [-999.0],
                                  dtype={"STATIONS_ID":int}
                                 )
            
            
            df_dummy =  df_dummy[['  RS','STATIONS_ID' ]]
            # Only interested in the daily precipitation height parameter

            df_dummy = df_dummy[(df_dummy.index.year >= 1950)] #readings only after 1950
            
            if df_prec_long.empty:
                df_prec_long = df_dummy
            else:
                df_prec_long = pd.concat([df_prec_long,df_dummy])

# %%
df_prec_long.head()
# Out:
#               RS  STATIONS_ID
# MESS_DATUM
# 1950-01-01   0.0           79
# 1950-01-02  13.0           79
# 1950-01-03   1.0           79
# 1950-01-04   2.8           79
# 1950-01-05   0.8           79

# %%
translate2 = \
{'STATIONS_ID':'station_id',
 '  RS':'prec'}

# %%
df_prec_long.rename(columns=translate2,inplace=True)

# %%
df_prec_long.index.rename("date_day", inplace = True)

# %%
df_prec_long
# Out:
#             prec  station_id
# date_day
# 1950-01-01   0.0          79
# 1950-01-02  13.0          79
# 1950-01-03   1.0          79
# 1950-01-04   2.8          79
# 1950-01-05   0.8          79
# ...          ...         ...
# 2023-12-27   0.0        5791
# 2023-12-28   0.0        5791
# 2023-12-29   1.0        5791
# 2023-12-30   0.3        5791
# 2023-12-31   0.0        5791
#
# [2143899 rows x 2 columns]

# %%
# %%time 
df_prec_long.to_csv("../data/time_series_prec_NRW.csv", sep= ";")
# Out:
# CPU times: total: 8.22 s
# Wall time: 11 s

# %%
df_prec_long.max(axis=0, skipna=True, numeric_only=False)
# Out:
# prec           161.7
# station_id    5791.0
# dtype: float64

# %%
df_prec_long.min(axis=0, skipna=True, numeric_only=False)
# Out:
# prec           0.0
# station_id    79.0
# dtype: float64

# %%
df_prec_long.mean(axis=0, skipna=True, numeric_only=False)
# Out:
# prec             2.439929
# station_id    2786.615242
# dtype: float64

# %%
df_prec_long.median(axis=0, skipna=True, numeric_only=False)
# Out:
# prec             0.2
# station_id    2744.0
# dtype: float64
